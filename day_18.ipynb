# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1=pd.read_csv('df1')
df2=pd.read_csv('df2')
df3=pd.read_csv('df3')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   object
#  1   A           1000 non-null   float64
#  2   B           1000 non-null   float64
#  3   C           1000 non-null   float64
#  4   D           1000 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %%
df2.head()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %% [markdown]
# #Graph Function
# 1.plot                       -Simple line plot
# 2.plot.area                  -filled version of line plot
# 3.plot.bar / plot.barh       -Bar graph
# 4.plot.box                   -Box plot
# 5.plot.density               -Density line (smooth curve)
# 6.plot.hexbin                -Hexagon version of scattter with density
# 7.plot.hist                  -histogram
# 8.plot.kde                   -Kernel Density estimator (density Graph)
# 10.plot.pie                  -Pie Chart of Categorical data
# 11.plot.scatter              -Scatter Graph

# %%
df3.head()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
fig = plt.figure(figsize = (20,20))
df2.plot(); plt.title('Line Plot');
df2.plot.area(); plt.title('Area Plot') 
df2.plot.bar(); plt.title('Bar Plot') 
df2.plot.box(); plt.title('Box Plot') 
df2.plot.barh(); plt.title('Bar Horizontal Plot') 
df2.plot.density(); plt.title('Density Plot') 
df2.plot.kde(); plt.title('KDE Plot') 
df2['a'].plot.hist(); plt.title('Histogram Plot') 
df2.plot.scatter(x='a', y= 'b' ); plt.title('Scatter Plot') 
df2.plot.hexbin(x='a', y='b' , C='c' , gridsize=6); plt.title('Hexbin Plot')
# Out:
# Text(0.5, 1.0, 'Hexbin Plot')

# %%
df4=pd.DataFrame({'Gift':[40,60,80,100],'name':['Rahul','Abhay','Anas','awasthi']})
df4['Gift'].plot.pie(autopct='%d%%', labels = df4['name'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\AAkash\Desktop\python training\DAY_18.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/AAkash/Desktop/python%20training/DAY_18.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> df4=pd.DataFrame({'Gift':[40,60,80,NaN],'name':['Rahul','Abhay','Anas','awasthi']})
#       <a href='vscode-notebook-cell:/c%3A/Users/AAkash/Desktop/python%20training/DAY_18.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> df4['Gift'].plot.pie(autopct='%d%%', labels = df4['name'])
#
# NameError: name 'NaN' is not defined
